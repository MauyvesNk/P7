# %% [markdown]
# # Partie IV - Réglage des hyperparamètres LightGBM avec Optuna

# %% [markdown]
# ### Importation de l'Environnement et des Données

# %%
# Importation des bibliothèques nécessaires

import sys
from yellowbrick.classifier import (
    ClassificationReport,
    ConfusionMatrix,
    DiscriminationThreshold,
    ROCAUC,
    PrecisionRecallCurve,
)
import yellowbrick
from optuna import Trial, visualization
import optuna
from lightgbm import LGBMClassifier
import lightgbm as lgbm
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    fbeta_score,
    make_scorer,
    precision_recall_fscore_support,
    log_loss,
    roc_auc_score,
    roc_curve,
    precision_recall_curve,
    auc,
)
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import (
    KFold,
    StratifiedKFold,
    cross_validate,
    cross_val_score,
    GridSearchCV,
    RepeatedStratifiedKFold,
    train_test_split,
)
import sklearn
import warnings
import pandas as pd
import numpy as np
import scipy.stats as stats
import time

# Visualisation
import seaborn as sns
from xplotter.insights import *
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = 6, 4

# Configuration du style seaborn et de la palette de couleurs
sns.set_style("ticks")
sns.color_palette("pink", as_cmap=True)

# Modélisation
# Configuration de l'affichage des nombres
pd.set_option('display.float_format', '{:,.2f}'.format)

# Désactivation des avertissements
warnings.filterwarnings('ignore')

# Affichage des versions des bibliothèques utilisées
print("python version", sys.version)
print("pandas version :", pd.__version__)
print("numpy version :", np.__version__)
print("matplotlib version :", matplotlib.__version__)
print("seaborn version :", sns.__version__)
print("sklearn version :", sklearn.__version__)
print("lightgbm version :", lgbm.__version__)
print("optuna version :", optuna.__version__)
print("yellowbrick version :", yellowbrick.__version__)
# Out:
# python version 3.11.5 (main, Sep 11 2023, 08:19:27) [Clang 14.0.6 ]
# pandas version : 2.0.3
# numpy version : 1.24.3
# matplotlib version : 3.7.2
# seaborn version : 0.12.2
# sklearn version : 1.3.2
# lightgbm version : 3.3.5
# optuna version : 3.4.0
# yellowbrick version : 1.5

# %% [markdown]
# ## Importation des données

# %% [markdown]
# Nous n'avons pas besoin de standardiser les variables car dans les modèles arborescents, l'échelle des caractéristiques n'a pas d'importance. En effet, à chaque niveau d'arborescence, le score d'une division possible sera égal, que l'entité respective ait été mise à l'échelle ou non. La mise à l'échelle est effectuée pour normaliser les données afin que la priorité ne soit pas donnée à une fonctionnalité particulière. Le rôle de la mise à l'échelle est principalement important dans les algorithmes basés sur la distance et nécessitant une distance euclidienne.

# %%
# Chargement des données totales filtrées et analysées
# X_train contient les caractéristiques des clients
# y contient la variable cible (1: Défaut de paiement, 0: Pas de défaut)

X = pd.read_csv('./Data/X_train.csv')
X.drop(labels='sk_id_curr', axis=1, inplace=True)

y = pd.read_csv('./Data/y.csv')

# Affichage des dimensions des ensembles de données
X.shape, y.shape
# Out:
# ((44063, 59), (44063, 1))

# %%
# Affichage des informations sur les caractéristiques des clients (X)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44063 entries, 0 to 44062
# Data columns (total 59 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   region_rating_client                                44063 non-null  int64
#  1   ext_source_2                                        44063 non-null  float64
#  2   taille_famille                                      44063 non-null  int64
#  3   age_client                                          44063 non-null  int64
#  4   anciennete_entreprise                               44063 non-null  int64
#  5   anciennete_cni                                      44063 non-null  int64
#  6   anciennete_portable                                 44063 non-null  int64
#  7   year_registration                                   44063 non-null  int64
#  8   heure_demande_pret                                  44063 non-null  int64
#  9   pop_region                                          44063 non-null  int64
#  10  taux_endettement                                    44063 non-null  int64
#  11  duree_remboursement                                 44063 non-null  int64
#  12  total_revenus                                       44063 non-null  int64
#  13  montant_credit                                      44063 non-null  int64
#  14  nb_demande_pret_precedente                          44063 non-null  float64
#  15  montant_demande_pret_precedente                     44063 non-null  float64
#  16  heure_demande_pret_precedente                       44063 non-null  float64
#  17  nb_year_depuis_decision_precedente                  44063 non-null  float64
#  18  prev_contrat_statut_canceled_unused                 44063 non-null  float64
#  19  prev_contrat_statut_refused                         44063 non-null  float64
#  20  prev_contrat_type_consumer_loans                    44063 non-null  float64
#  21  prev_contrat_type_revolving_loans                   44063 non-null  float64
#  22  num_instalment_version                              44063 non-null  float64
#  23  num_instalment_number                               44063 non-null  float64
#  24  montant_paye_vs_du                                  44063 non-null  float64
#  25  days_past_due                                       44063 non-null  float64
#  26  days_before_due                                     44063 non-null  float64
#  27  days_credit                                         44063 non-null  float64
#  28  amt_credit_sum                                      44063 non-null  float64
#  29  bureau_credit_actif_closed                          44063 non-null  float64
#  30  bureau_credit_actif_sold_bad_debt                   44063 non-null  float64
#  31  bureau_credit_type_credit_card                      44063 non-null  float64
#  32  bureau_credit_type_other_credit                     44063 non-null  float64
#  33  solde_credit_bureau_statut_actif_avec_jours_retard  44063 non-null  float64
#  34  solde_credit_bureau_statut_closed                   44063 non-null  float64
#  35  cnt_instalment                                      44063 non-null  float64
#  36  name_contract_type_revolving_loans                  44063 non-null  bool
#  37  code_gender_Homme                                   44063 non-null  bool
#  38  flag_own_car_Y                                      44063 non-null  bool
#  39  flag_own_realty_Y                                   44063 non-null  bool
#  40  name_type_suite_Famille                             44063 non-null  bool
#  41  name_type_suite_Unaccompanied                       44063 non-null  bool
#  42  name_income_type_employé                            44063 non-null  bool
#  43  name_income_type_fonctionnaire                      44063 non-null  bool
#  44  name_income_type_retraité_ou_sans_emploi            44063 non-null  bool
#  45  name_education_type_enseignement_superieur          44063 non-null  bool
#  46  name_family_status_sans_partenaire                  44063 non-null  bool
#  47  name_housing_type_maison_appartement                44063 non-null  bool
#  48  flag_emp_phone_Oui                                  44063 non-null  bool
#  49  flag_work_phone_Oui                                 44063 non-null  bool
#  50  flag_phone_Oui                                      44063 non-null  bool
#  51  reg_region_not_live_region_adresse_identique        44063 non-null  bool
#  52  reg_region_not_work_region_adresse_identique        44063 non-null  bool
#  53  reg_city_not_live_city_adresse_identique            44063 non-null  bool
#  54  reg_city_not_work_city_adresse_identique            44063 non-null  bool
#  55  live_city_not_work_city_adresse_identique           44063 non-null  bool
#  56  flag_document_3_Oui                                 44063 non-null  bool
#  57  flag_document_6_Oui                                 44063 non-null  bool
#  58  flag_document_8_Oui                                 44063 non-null  bool
# dtypes: bool(23), float64(23), int64(13)
# memory usage: 13.1 MB

# %%
# Importation de la fonction plot_countplot du module xplotter.insights
from xplotter.insights import *

# Définition de la palette de couleurs
colors = ['#d4b3ac']

# Mapping des étiquettes de la cible (1: "is_difficulty_payment", 0: "not_difficulty_payment")
loan_map = {1 : "is_difficulty_payment",
            0 : "not_difficulty_payment"}

# Création de la figure et des axes
fig, ax = plt.subplots(figsize=(6, 4))
# Utilisation de la fonction plot_countplot pour afficher le diagramme à barres
plot_countplot(df=y, 
               col='target', 
               label_names=loan_map,
               order=True,
               palette=colors, ax=ax, orient='v', size_labels=12)
# Ajout du titre au graphique
plt.title("Le client est-il en difficulté de paiement ?\n",
           loc="center", fontsize=18, fontstyle='italic')

# Affichage du graphique
plt.tight_layout()
plt.show()

# %% [markdown]
# # Optimisation des hyperparamètres avec Optuna du modèle LightGBM

# %%
# Importation de la fonction LightGBMPruningCallback du module optuna.integration
from optuna.integration import LightGBMPruningCallback

def objective(trial, X, y):
    
    # Définition de la grille des hyperparamètres
    param_grid = {
        "objective": "binary",
        "class_weight": "balanced",
        "verbose": -1,
        "boosting_type": "gbdt",
        "n_estimators": trial.suggest_int("n_estimators", 50, 500, step=50),
        "learning_rate": trial.suggest_float("learning_rate", 1e-7, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 12, step=2),
        "num_leaves": trial.suggest_int("num_leaves", 3, 12, step=2),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 200, 10000, step=100),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "lambda_l1": trial.suggest_loguniform("lambda_l1", 1e-8, 10.0),
        "lambda_l2": trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
        "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
        "feature_fraction": trial.suggest_uniform("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_uniform("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.3, 0.8 , step=1),
    }
    
    # Définition de la stratégie de validation croisée
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=101)
    # Initialisation d'un tableau pour stocker les scores de validation croisée
    cv_scores = np.empty(5)
    
    # Boucle sur les plis de la validation croisée
    for idx, (train_index, test_index) in enumerate(cv.split(X, y)):
        # Séparation des données d'entraînement et de test       
        X_train, X_test = X.take(list(train_index),axis=0), X.take(list(test_index),axis=0)
        y_train, y_test = y.take(list(train_index),axis=0), y.take(list(test_index),axis=0)
        
        # Initialisation et entraînement du modèle
        model = lgbm.LGBMClassifier(**param_grid, n_jobs=-2, random_state=101)
        model.fit(
            X_train,
            y_train,
            eval_set=[(X_test, y_test)],
            eval_metric="binary_logloss",
            early_stopping_rounds=100,
            callbacks=[LightGBMPruningCallback(trial, "binary_logloss")])  # Ajout d'un rappel de coupure
        
        # Prédictions et calcul du score de log loss
        preds = model.predict_proba(X_test)
        cv_scores[idx] = log_loss(y_test, preds)
     # Retour de la moyenne des scores de log loss           
    return np.mean(cv_scores)

# %%
# Chronométrer le temps d'exécution
# %%time

# Création de l'étude visant à minimiser
study = optuna.create_study(direction="minimize", study_name="LGBM Classifier")
# Définition de la fonction objectif avec la grille d'hyperparamètres
func = lambda trial: objective(trial, X, y)
# Optimisation de la fonction objectif avec 300 essais
study.optimize(func, n_trials=300)
# Out:
# [I 2023-11-18 22:00:26,573] A new study created in memory with name: LGBM Classifier
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=8.278035915965635, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.278035915965635
# [LightGBM] [Warning] feature_fraction is set=0.5283169629207864, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5283169629207864
# [LightGBM] [Warning] bagging_fraction is set=0.9068626980395347, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9068626980395347
# [LightGBM] [Warning] lambda_l2 is set=0.0006685501867556522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0006685501867556522
# [LightGBM] [Warning] min_data_in_leaf is set=3300, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=3300
# [LightGBM] [Warning] lambda_l1 is set=2.9157588275879286e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.9157588275879286e-08
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=8.278035915965635, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.278035915965635
# [LightGBM] [Warning] feature_fraction is set=0.5283169629207864, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5283169629207864
# [LightGBM] [Warning] bagging_fraction is set=0.9068626980395347, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9068626980395347
# [LightGBM] [Warning] lambda_l2 is set=0.0006685501867556522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0006685501867556522
# [LightGBM] [Warning] min_data_in_leaf is set=3300, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=3300
# [LightGBM] [Warning] lambda_l1 is set=2.9157588275879286e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.9157588275879286e-08
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=8.278035915965635, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.278035915965635
# [LightGBM] [Warning] feature_fraction is set=0.5283169629207864, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5283169629207864
# [LightGBM] [Warning] bagging_fraction is set=0.9068626980395347, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9068626980395347
# [LightGBM] [Warning] lambda_l2 is set=0.0006685501867556522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0006685501867556522
# [LightGBM] [Warning] min_data_in_leaf is set=3300, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=3300
# [LightGBM] [Warning] lambda_l1 is set=2.9157588275879286e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.9157588275879286e-08
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=8.278035915965635, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.278035915965635
# [LightGBM] [Warning] feature_fraction is set=0.5283169629207864, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5283169629207864
# [LightGBM] [Warning] bagging_fraction is set=0.9068626980395347, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9068626980395347
# [LightGBM] [Warning] lambda_l2 is set=0.0006685501867556522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0006685501867556522
# [LightGBM] [Warning] min_data_in_leaf is set=3300, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=3300
# [LightGBM] [Warning] lambda_l1 is set=2.9157588275879286e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.9157588275879286e-08
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=8.278035915965635, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.278035915965635
# [LightGBM] [Warning] feature_fraction is set=0.5283169629207864, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5283169629207864
# [LightGBM] [Warning] bagging_fraction is set=0.9068626980395347, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9068626980395347
# [LightGBM] [Warning] lambda_l2 is set=0.0006685501867556522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0006685501867556522
# [LightGBM] [Warning] min_data_in_leaf is set=3300, min_child_samples=93 will be ignored. Current value: min_data_in_leaf=3300
# [LightGBM] [Warning] lambda_l1 is set=2.9157588275879286e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.9157588275879286e-08
# [I 2023-11-18 22:00:37,795] Trial 0 finished with value: 0.6639640777235377 and parameters: {'n_estimators': 200, 'learning_rate': 0.003366014089945051, 'max_depth': 7, 'num_leaves': 5, 'min_data_in_leaf': 3300, 'min_child_samples': 93, 'lambda_l1': 2.9157588275879286e-08, 'lambda_l2': 0.0006685501867556522, 'min_gain_to_split': 8.278035915965635, 'feature_fraction': 0.5283169629207864, 'bagging_fraction': 0.9068626980395347, 'bagging_freq': 6, 'colsample_bytree': 0.3}. Best is trial 0 with value: 0.6639640777235377.
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=5.6675019151599795, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.6675019151599795
# [LightGBM] [Warning] feature_fraction is set=0.6372383585612724, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6372383585612724
# [LightGBM] [Warning] bagging_fraction is set=0.6759325601236069, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6759325601236069
# [LightGBM] [Warning] lambda_l2 is set=0.11045570474677115, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11045570474677115
# [LightGBM] [Warning] min_data_in_leaf is set=5200, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=5200
# [LightGBM] [Warning] lambda_l1 is set=5.602664828226105, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.602664828226105
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=5.6675019151599795, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.6675019151599795
# [LightGBM] [Warning] feature_fraction is set=0.6372383585612724, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6372383585612724
# [LightGBM] [Warning] bagging_fraction is set=0.6759325601236069, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6759325601236069
# [LightGBM] [Warning] lambda_l2 is set=0.11045570474677115, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11045570474677115
# [LightGBM] [Warning] min_data_in_leaf is set=5200, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=5200
# [LightGBM] [Warning] lambda_l1 is set=5.602664828226105, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.602664828226105
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=5.6675019151599795, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.6675019151599795
# [LightGBM] [Warning] feature_fraction is set=0.6372383585612724, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6372383585612724
# [LightGBM] [Warning] bagging_fraction is set=0.6759325601236069, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6759325601236069
# [LightGBM] [Warning] lambda_l2 is set=0.11045570474677115, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11045570474677115
# [LightGBM] [Warning] min_data_in_leaf is set=5200, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=5200
# [LightGBM] [Warning] lambda_l1 is set=5.602664828226105, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.602664828226105
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=5.6675019151599795, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.6675019151599795
# [LightGBM] [Warning] feature_fraction is set=0.6372383585612724, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6372383585612724
# [LightGBM] [Warning] bagging_fraction is set=0.6759325601236069, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6759325601236069
# [LightGBM] [Warning] lambda_l2 is set=0.11045570474677115, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11045570474677115
# [LightGBM] [Warning] min_data_in_leaf is set=5200, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=5200
# [LightGBM] [Warning] lambda_l1 is set=5.602664828226105, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.602664828226105
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=5.6675019151599795, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.6675019151599795
# [LightGBM] [Warning] feature_fraction is set=0.6372383585612724, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6372383585612724
# [LightGBM] [Warning] bagging_fraction is set=0.6759325601236069, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6759325601236069
# [LightGBM] [Warning] lambda_l2 is set=0.11045570474677115, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11045570474677115
# [LightGBM] [Warning] min_data_in_leaf is set=5200, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=5200
# [LightGBM] [Warning] lambda_l1 is set=5.602664828226105, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.602664828226105
# [I 2023-11-18 22:00:45,486] Trial 1 finished with value: 0.6931402312364033 and parameters: {'n_estimators': 400, 'learning_rate': 3.4964588542915196e-07, 'max_depth': 3, 'num_leaves': 5, 'min_data_in_leaf': 5200, 'min_child_samples': 43, 'lambda_l1': 5.602664828226105, 'lambda_l2': 0.11045570474677115, 'min_gain_to_split': 5.6675019151599795, 'feature_fraction': 0.6372383585612724, 'bagging_fraction': 0.6759325601236069, 'bagging_freq': 7, 'colsample_bytree': 0.3}. Best is trial 0 with value: 0.6639640777235377.
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=14.977378461737704, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.977378461737704
# [LightGBM] [Warning] feature_fraction is set=0.8934377474363613, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8934377474363613
# [LightGBM] [Warning] bagging_fraction is set=0.5986926914341918, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5986926914341918
# [LightGBM] [Warning] lambda_l2 is set=7.074823049033682, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.074823049033682
# [LightGBM] [Warning] min_data_in_leaf is set=6800, min_child_samples=59 will be ignored. Current value: min_data_in_leaf=6800
# [LightGBM] [Warning] lambda_l1 is set=0.00019325871297392092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00019325871297392092
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=14.977378461737704, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.977378461737704
# [LightGBM] [Warning] feature_fraction is set=0.8934377474363613, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8934377474363613
# [LightGBM] [Warning] bagging_fraction is set=0.5986926914341918, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5986926914341918
# [LightGBM] [Warning] lambda_l2 is set=7.074823049033682, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.074823049033682
# [LightGBM] [Warning] min_data_in_leaf is set=6800, min_child_samples=59 will be ignored. Current value: min_data_in_leaf=6800
# [LightGBM] [Warning] lambda_l1 is set=0.00019325871297392092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00019325871297392092
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=14.977378461737704, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.977378461737704
# [LightGBM] [Warning] feature_fraction is set=0.8934377474363613, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8934377474363613
# [LightGBM] [Warning] bagging_fraction is set=0.5986926914341918, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5986926914341918
# [LightGBM] [Warning] lambda_l2 is set=7.074823049033682, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.074823049033682
# [LightGBM] [Warning] min_data_in_leaf is set=6800, min_child_samples=59 will be ignored. Current value: min_data_in_leaf=6800
# [LightGBM] [Warning] lambda_l1 is set=0.00019325871297392092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00019325871297392092
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=14.977378461737704, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.977378461737704
# [LightGBM] [Warning] feature_fraction is set=0.8934377474363613, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8934377474363613
# [LightGBM] [Warning] bagging_fraction is set=0.5986926914341918, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5986926914341918
# [LightGBM] [Warning] lambda_l2 is set=7.074823049033682, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.074823049033682
# [LightGBM] [Warning] min_data_in_leaf is set=6800, min_child_samples=59 will be ignored. Current value: min_data_in_leaf=6800
# [LightGBM] [Warning] lambda_l1 is set=0.00019325871297392092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00019325871297392092
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=14.977378461737704, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.977378461737704
# [LightGBM] [Warning] feature_fraction is set=0.8934377474363613, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8934377474363613
# [LightGBM] [Warning] bagging_fraction is set=0.5986926914341918, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5986926914341918
# [LightGBM] [Warning] lambda_l2 is set=7.074823049033682, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.074823049033682
# [LightGBM] [Warning] min_data_in_leaf is set=6800, min_child_samples=59 will be ignored. Current value: min_data_in_leaf=6800
# [LightGBM] [Warning] lambda_l1 is set=0.00019325871297392092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00019325871297392092
# [I 2023-11-18 22:00:52,552] Trial 2 finished with value: 0.6709139854458247 and parameters: {'n_estimators': 400, 'learning_rate': 0.0016704908959552104, 'max_depth': 5, 'num_leaves': 5, 'min_data_in_leaf': 6800, 'min_child_samples': 59, 'lambda_l1': 0.00019325871297392092, 'lambda_l2': 7.074823049033682, 'min_gain_to_split': 14.977378461737704, 'feature_fraction': 0.8934377474363613, 'bagging_fraction': 0.5986926914341918, 'bagging_freq': 7, 'colsample_bytree': 0.3}. Best is trial 0 with value: 0.6639640777235377.
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=3.941212892652311, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.941212892652311
# [LightGBM] [Warning] feature_fraction is set=0.5514223655541001, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5514223655541001
# [LightGBM] [Warning] bagging_fraction is set=0.46525464054918947, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46525464054918947
# [LightGBM] [Warning] lambda_l2 is set=4.624668283372751e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.624668283372751e-08
# [LightGBM] [Warning] min_data_in_leaf is set=7900, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=7900
# [LightGBM] [Warning] lambda_l1 is set=7.2467873793819524e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2467873793819524e-06
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=3.941212892652311, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.941212892652311
# [LightGBM] [Warning] feature_fraction is set=0.5514223655541001, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5514223655541001
# [LightGBM] [Warning] bagging_fraction is set=0.46525464054918947, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46525464054918947
# [LightGBM] [Warning] lambda_l2 is set=4.624668283372751e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.624668283372751e-08
# [LightGBM] [Warning] min_data_in_leaf is set=7900, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=7900
# [LightGBM] [Warning] lambda_l1 is set=7.2467873793819524e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2467873793819524e-06
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=3.941212892652311, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.941212892652311
# [LightGBM] [Warning] feature_fraction is set=0.5514223655541001, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5514223655541001
# [LightGBM] [Warning] bagging_fraction is set=0.46525464054918947, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46525464054918947
# [LightGBM] [Warning] lambda_l2 is set=4.624668283372751e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.624668283372751e-08
# [LightGBM] [Warning] min_data_in_leaf is set=7900, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=7900
# [LightGBM] [Warning] lambda_l1 is set=7.2467873793819524e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2467873793819524e-06
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=3.941212892652311, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.941212892652311
# [LightGBM] [Warning] feature_fraction is set=0.5514223655541001, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5514223655541001
# [LightGBM] [Warning] bagging_fraction is set=0.46525464054918947, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46525464054918947
# [LightGBM] [Warning] lambda_l2 is set=4.624668283372751e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.624668283372751e-08
# [LightGBM] [Warning] min_data_in_leaf is set=7900, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=7900
# [LightGBM] [Warning] lambda_l1 is set=7.2467873793819524e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2467873793819524e-06
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] min_gain_to_split is set=3.941212892652311, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.941212892652311
# [LightGBM] [Warning] feature_fraction is set=0.5514223655541001, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.5514223655541001
# [LightGBM] [Warning] bagging_fraction is set=0.46525464054918947, subsample=1.0 will be ignored. Current value: bagging_fraction=0.46525464054918947
# [LightGBM] [Warning] lambda_l2 is set=4.624668283372751e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.624668283372751e-08
# [LightGBM] [Warning] min_data_in_leaf is set=7900, min_child_samples=54 will be ignored. Current value: min_data_in_leaf=7900
# [LightGBM] [Warning] lambda_l1 is set=7.2467873793819524e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.2467873793819524e-06
# [I 2023-11-18 22:01:19,292] Trial 3 finished with value: 0.6931128473763605 and parameters: {'n_estimators': 450, 'learning_rate': 2.388451497186024e-06, 'max_depth': 7, 'num_leaves': 9, 'min_data_in_leaf': 7900, 'min_child_samples': 54, 'lambda_l1': 7.2467873793819524e-06, 'lambda_l2': 4.624668283372751e-08, 'min_gain_to_split': 3.941212892652311, 'feature_fraction': 0.5514223655541001, 'bagging_fraction': 0.46525464054918947, 'bagging_freq': 6, 'colsample_bytree': 0.3}. Best is trial 0 with value: 0.6639640777235377.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.505030277757471, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.505030277757471
# [LightGBM] [Warning] feature_fraction is set=0.6147868136937948, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6147868136937948
# [LightGBM] [Warning] bagging_fraction is set=0.9890630162327766, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9890630162327766
# [LightGBM] [Warning] lambda_l2 is set=2.3876256888212253, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3876256888212253
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=5.050135145342945e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.050135145342945e-06
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.505030277757471, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.505030277757471
# [LightGBM] [Warning] feature_fraction is set=0.6147868136937948, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6147868136937948
# [LightGBM] [Warning] bagging_fraction is set=0.9890630162327766, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9890630162327766
# [LightGBM] [Warning] lambda_l2 is set=2.3876256888212253, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3876256888212253
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=5.050135145342945e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.050135145342945e-06
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.505030277757471, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.505030277757471
# [LightGBM] [Warning] feature_fraction is set=0.6147868136937948, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6147868136937948
# [LightGBM] [Warning] bagging_fraction is set=0.9890630162327766, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9890630162327766
# [LightGBM] [Warning] lambda_l2 is set=2.3876256888212253, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3876256888212253
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=5.050135145342945e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.050135145342945e-06
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.505030277757471, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.505030277757471
# [LightGBM] [Warning] feature_fraction is set=0.6147868136937948, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6147868136937948
# [LightGBM] [Warning] bagging_fraction is set=0.9890630162327766, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9890630162327766
# [LightGBM] [Warning] lambda_l2 is set=2.3876256888212253, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3876256888212253
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=5.050135145342945e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.050135145342945e-06
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.505030277757471, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.505030277757471
# [LightGBM] [Warning] feature_fraction is set=0.6147868136937948, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.6147868136937948
# [LightGBM] [Warning] bagging_fraction is set=0.9890630162327766, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9890630162327766
# [LightGBM] [Warning] lambda_l2 is set=2.3876256888212253, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3876256888212253
# [LightGBM] [Warning] min_data_in_leaf is set=400, min_child_samples=87 will be ignored. Current value: min_data_in_leaf=400
# [LightGBM] [Warning] lambda_l1 is set=5.050135145342945e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.050135145342945e-06
# [I 2023-11-18 22:01:38,473] Trial 4 finished with value: 0.6931423188333461 and parameters: {'n_estimators': 500, 'learning_rate': 1.2479788374682755e-07, 'max_depth': 11, 'num_leaves': 11, 'min_data_in_leaf': 400, 'min_child_samples': 87, 'lambda_l1': 5.050135145342945e-06, 'lambda_l2': 2.3876256888212253, 'min_gain_to_split': 5.505030277757471, 'feature_fraction': 0.6147868136937948, 'bagging_fraction': 0.9890630162327766, 'bagging_freq': 1, 'colsample_bytree': 0.3}. Best is trial 0 with value: 0.6639640777235377.
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=12.141405939743239, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=12.141405939743239
# [LightGBM] [Warning] feature_fraction is set=0.7668103199082135, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.7668103199082135
# [LightGBM] [Warning] bagging_fraction is set=0.8295680549292495, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8295680549292495
# [LightGBM] [Warning] lambda_l2 is set=2.0187067877459008e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0187067877459008e-08
# [LightGBM] [Warning] min_data_in_leaf is set=700, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=700
# [LightGBM] [Warning] lambda_l1 is set=0.0010279058390387833, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0010279058390387833
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=12.141405939743239, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=12.141405939743239
# [LightGBM] [Warning] feature_fraction is set=0.7668103199082135, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.7668103199082135
# [LightGBM] [Warning] bagging_fraction is set=0.8295680549292495, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8295680549292495
# [LightGBM] [Warning] lambda_l2 is set=2.0187067877459008e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0187067877459008e-08
# [LightGBM] [Warning] min_data_in_leaf is set=700, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=700
# [LightGBM] [Warning] lambda_l1 is set=0.0010279058390387833, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0010279058390387833
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=12.141405939743239, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=12.141405939743239
# [LightGBM] [Warning] feature_fraction is set=0.7668103199082135, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.7668103199082135
# [LightGBM] [Warning] bagging_fraction is set=0.8295680549292495, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8295680549292495
# [LightGBM] [Warning] lambda_l2 is set=2.0187067877459008e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0187067877459008e-08
# [LightGBM] [Warning] min_data_in_leaf is set=700, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=700
# [LightGBM] [Warning] lambda_l1 is set=0.0010279058390387833, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0010279058390387833
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=12.141405939743239, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=12.141405939743239
# [LightGBM] [Warning] feature_fraction is set=0.7668103199082135, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.7668103199082135
# [LightGBM] [Warning] bagging_fraction is set=0.8295680549292495, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8295680549292495
# [LightGBM] [Warning] lambda_l2 is set=2.0187067877459008e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0187067877459008e-08
# [LightGBM] [Warning] min_data_in_leaf is set=700, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=700
# [LightGBM] [Warning] lambda_l1 is set=0.0010279058390387833, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0010279058390387833
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# [LightGBM] [Warning] min_gain_to_split is set=12.141405939743239, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=12.141405939743239
# [LightGBM] [Warning] feature_fraction is set=0.7668103199082135, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.7668103199082135
# [LightGBM] [Warning] bagging_fraction is set=0.8295680549292495, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8295680549292495
# [LightGBM] [Warning] lambda_l2 is set=2.0187067877459008e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.0187067877459008e-08
# [LightGBM] [Warning] min_data_in_leaf is set=700, min_child_samples=78 will be ignored. Current value: min_data_in_leaf=700
# [LightGBM] [Warning] lambda_l1 is set=0.0010279058390387833, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0010279058390387833
# [I 2023-11-18 22:01:42,585] Trial 5 finished with value: 0.6931383543779461 and parameters: {'n_estimators': 50, 'learning_rate': 2.5655517817040025e-06, 'max_depth': 9, 'num_leaves': 5, 'min_data_in_leaf': 700, 'min_child_samples': 78, 'lambda_l1': 0.0010279058390387833, 'lambda_l2': 2.0187067877459008e-08, 'min_gain_to_split': 12.141405939743239, 'feature_fraction': 0.7668103199082135, 'bagging_fraction': 0.8295680549292495, 'bagging_freq': 7, 'colsample_bytree': 0.3}. Best is trial 0 with value: 0.6639640777235377.
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] min_gain_to_split is set=1.973426151818118, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.973426151818118
# [LightGBM] [Warning] feature_fraction is set=0.9391500433924093, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9391500433924093
# [LightGBM] [Warning] bagging_fraction is set=0.4853523758758691, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4853523758758691
# [LightGBM] [Warning] lambda_l2 is set=0.14943679301513438, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14943679301513438
# [LightGBM] [Warning] min_data_in_leaf is set=9100, min_child_samples=38 will be ignored. Current value: min_data_in_leaf=9100
# [LightGBM] [Warning] lambda_l1 is set=2.7434017415794845, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.7434017415794845
# [I 2023-11-18 22:01:43,065] Trial 6 pruned. Trial was pruned at iteration 0.
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] min_gain_to_split is set=14.023310153774556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.023310153774556
# [LightGBM] [Warning] feature_fraction is set=0.41866478415484304, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.41866478415484304
# [LightGBM] [Warning] bagging_fraction is set=0.900162056394264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.900162056394264
# [LightGBM] [Warning] lambda_l2 is set=2.435583637985142e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.435583637985142e-05
# [LightGBM] [Warning] min_data_in_leaf is set=4300, min_child_samples=19 will be ignored. Current value: min_data_in_leaf=4300
# [LightGBM] [Warning] lambda_l1 is set=9.738491074397754e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.738491074397754e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] min_gain_to_split is set=14.023310153774556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.023310153774556
# [LightGBM] [Warning] feature_fraction is set=0.41866478415484304, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.41866478415484304
# [LightGBM] [Warning] bagging_fraction is set=0.900162056394264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.900162056394264
# [LightGBM] [Warning] lambda_l2 is set=2.435583637985142e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.435583637985142e-05
# [LightGBM] [Warning] min_data_in_leaf is set=4300, min_child_samples=19 will be ignored. Current value: min_data_in_leaf=4300
# [LightGBM] [Warning] lambda_l1 is set=9.738491074397754e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.738491074397754e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] min_gain_to_split is set=14.023310153774556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.023310153774556
# [LightGBM] [Warning] feature_fraction is set=0.41866478415484304, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.41866478415484304
# [LightGBM] [Warning] bagging_fraction is set=0.900162056394264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.900162056394264
# [LightGBM] [Warning] lambda_l2 is set=2.435583637985142e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.435583637985142e-05
# [LightGBM] [Warning] min_data_in_leaf is set=4300, min_child_samples=19 will be ignored. Current value: min_data_in_leaf=4300
# [LightGBM] [Warning] lambda_l1 is set=9.738491074397754e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.738491074397754e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] min_gain_to_split is set=14.023310153774556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=14.023310153774556
# [LightGBM] [Warning] feature_fraction is set=0.41866478415484304, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.41866478415484304
# [LightGBM] [Warning] bagging_fraction is set=0.900162056394264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.900162056394264
# [LightGBM] [Warning] lambda_l2 is set=2.435583637985142e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.435583637985142e-05
# [LightGBM] [Warning] min_data_in_leaf is set=4300, min_child_samples=19 will be ignored. Current value: min_data_in_leaf=4300
# [LightGBM] [Warning] lambda_l1 is set=9.738491074397754e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.738491074397754e-08
# [I 2023-11-18 22:01:48,913] Trial 7 finished with value: 0.6675878725616938 and parameters: {'n_estimators': 100, 'learning_rate': 0.006426171520666165, 'max_depth': 5, 'num_leaves': 5, 'min_data_in_leaf': 4300, 'min_child_samples': 19, 'lambda_l1': 9.738491074397754e-08, 'lambda_l2': 2.435583637985142e-05, 'min_gain_to_split': 14.023310153774556, 'feature_fraction': 0.41866478415484304, 'bagging_fraction': 0.900162056394264, 'bagging_freq': 5, 'colsample_bytree': 0.3}. Best is trial 0 with value: 0.6639640777235377.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] min_gain_to_split is set=1.106628224137639, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.106628224137639
# [LightGBM] [Warning] feature_fraction is set=0.8284345192696094, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8284345192696094
# [LightGBM] [Warning] bagging_fraction is set=0.7164846750458662, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7164846750458662
# [LightGBM] [Warning] lambda_l2 is set=0.00010522249574384101, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.00010522249574384101
# [LightGBM] [Warning] min_data_in_leaf is set=4900, min_child_samples=36 will be ignored. Current value: min_data_in_leaf=4900
# [LightGBM] [Warning] lambda_l1 is set=1.608610030446803, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.608610030446803
# [I 2023-11-18 22:01:49,597] Trial 8 pruned. Trial was pruned at iteration 50.
# [I 2023-11-18 22:01:50,075] Trial 9 pruned. Trial was pruned at iteration 0.
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.442238735921693, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.442238735921693
# [LightGBM] [Warning] feature_fraction is set=0.9952494380320875, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9952494380320875
# [LightGBM] [Warning] bagging_fraction is set=0.8148638976141931, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8148638976141931
# [LightGBM] [Warning] lambda_l2 is set=0.0016722813429445316, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0016722813429445316
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=98 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=4.163581415903386e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.163581415903386e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.442238735921693, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.442238735921693
# [LightGBM] [Warning] feature_fraction is set=0.9952494380320875, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9952494380320875
# [LightGBM] [Warning] bagging_fraction is set=0.8148638976141931, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8148638976141931
# [LightGBM] [Warning] lambda_l2 is set=0.0016722813429445316, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0016722813429445316
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=98 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=4.163581415903386e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.163581415903386e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.442238735921693, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.442238735921693
# [LightGBM] [Warning] feature_fraction is set=0.9952494380320875, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9952494380320875
# [LightGBM] [Warning] bagging_fraction is set=0.8148638976141931, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8148638976141931
# [LightGBM] [Warning] lambda_l2 is set=0.0016722813429445316, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0016722813429445316
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=98 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=4.163581415903386e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.163581415903386e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.442238735921693, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.442238735921693
# [LightGBM] [Warning] feature_fraction is set=0.9952494380320875, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9952494380320875
# [LightGBM] [Warning] bagging_fraction is set=0.8148638976141931, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8148638976141931
# [LightGBM] [Warning] lambda_l2 is set=0.0016722813429445316, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0016722813429445316
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=98 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=4.163581415903386e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.163581415903386e-08
# [I 2023-11-18 22:01:56,568] Trial 10 finished with value: 0.5900998778874336 and parameters: {'n_estimators': 250, 'learning_rate': 0.12109570437715203, 'max_depth': 11, 'num_leaves': 3, 'min_data_in_leaf': 2600, 'min_child_samples': 98, 'lambda_l1': 4.163581415903386e-08, 'lambda_l2': 0.0016722813429445316, 'min_gain_to_split': 8.442238735921693, 'feature_fraction': 0.9952494380320875, 'bagging_fraction': 0.8148638976141931, 'bagging_freq': 4, 'colsample_bytree': 0.3}. Best is trial 10 with value: 0.5900998778874336.
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.764480564929556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.764480564929556
# [LightGBM] [Warning] feature_fraction is set=0.9851958697006425, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9851958697006425
# [LightGBM] [Warning] bagging_fraction is set=0.8267780331892474, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8267780331892474
# [LightGBM] [Warning] lambda_l2 is set=0.0024943015898132854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0024943015898132854
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=1.1064218541990445e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1064218541990445e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.764480564929556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.764480564929556
# [LightGBM] [Warning] feature_fraction is set=0.9851958697006425, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9851958697006425
# [LightGBM] [Warning] bagging_fraction is set=0.8267780331892474, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8267780331892474
# [LightGBM] [Warning] lambda_l2 is set=0.0024943015898132854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0024943015898132854
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=1.1064218541990445e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1064218541990445e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.764480564929556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.764480564929556
# [LightGBM] [Warning] feature_fraction is set=0.9851958697006425, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9851958697006425
# [LightGBM] [Warning] bagging_fraction is set=0.8267780331892474, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8267780331892474
# [LightGBM] [Warning] lambda_l2 is set=0.0024943015898132854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0024943015898132854
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=1.1064218541990445e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1064218541990445e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.764480564929556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.764480564929556
# [LightGBM] [Warning] feature_fraction is set=0.9851958697006425, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9851958697006425
# [LightGBM] [Warning] bagging_fraction is set=0.8267780331892474, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8267780331892474
# [LightGBM] [Warning] lambda_l2 is set=0.0024943015898132854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0024943015898132854
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=1.1064218541990445e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1064218541990445e-08
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=8.764480564929556, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=8.764480564929556
# [LightGBM] [Warning] feature_fraction is set=0.9851958697006425, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.9851958697006425
# [LightGBM] [Warning] bagging_fraction is set=0.8267780331892474, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8267780331892474
# [LightGBM] [Warning] lambda_l2 is set=0.0024943015898132854, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0024943015898132854
# [LightGBM] [Warning] min_data_in_leaf is set=2600, min_child_samples=100 will be ignored. Current value: min_data_in_leaf=2600
# [LightGBM] [Warning] lambda_l1 is set=1.1064218541990445e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1064218541990445e-08
# ...
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.402805539011973, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.402805539011973
# [LightGBM] [Warning] feature_fraction is set=0.8344748721880672, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8344748721880672
# [LightGBM] [Warning] bagging_fraction is set=0.6394357593425052, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6394357593425052
# [LightGBM] [Warning] lambda_l2 is set=8.585333315461079e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.585333315461079e-07
# [LightGBM] [Warning] min_data_in_leaf is set=500, min_child_samples=68 will be ignored. Current value: min_data_in_leaf=500
# [LightGBM] [Warning] lambda_l1 is set=1.1958167060638846e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.1958167060638846e-07
# [I 2023-11-18 22:25:25,177] Trial 247 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:25,891] Trial 248 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:26,554] Trial 249 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:28,829] Trial 250 pruned. Trial was pruned at iteration 210.
# [I 2023-11-18 22:25:29,509] Trial 251 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:30,189] Trial 252 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:30,862] Trial 253 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:31,552] Trial 254 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:32,243] Trial 255 pruned. Trial was pruned at iteration 0.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.20781785472238, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.20781785472238
# [LightGBM] [Warning] feature_fraction is set=0.8217180972965641, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8217180972965641
# [LightGBM] [Warning] bagging_fraction is set=0.4130410980988764, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4130410980988764
# [LightGBM] [Warning] lambda_l2 is set=3.263654045312949e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.263654045312949e-06
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=5 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.0984604254136754e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0984604254136754e-07
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.20781785472238, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.20781785472238
# [LightGBM] [Warning] feature_fraction is set=0.8217180972965641, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8217180972965641
# [LightGBM] [Warning] bagging_fraction is set=0.4130410980988764, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4130410980988764
# [LightGBM] [Warning] lambda_l2 is set=3.263654045312949e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.263654045312949e-06
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=5 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.0984604254136754e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0984604254136754e-07
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.20781785472238, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.20781785472238
# [LightGBM] [Warning] feature_fraction is set=0.8217180972965641, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8217180972965641
# [LightGBM] [Warning] bagging_fraction is set=0.4130410980988764, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4130410980988764
# [LightGBM] [Warning] lambda_l2 is set=3.263654045312949e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.263654045312949e-06
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=5 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.0984604254136754e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0984604254136754e-07
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.20781785472238, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.20781785472238
# [LightGBM] [Warning] feature_fraction is set=0.8217180972965641, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8217180972965641
# [LightGBM] [Warning] bagging_fraction is set=0.4130410980988764, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4130410980988764
# [LightGBM] [Warning] lambda_l2 is set=3.263654045312949e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.263654045312949e-06
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=5 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.0984604254136754e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0984604254136754e-07
# [I 2023-11-18 22:25:50,714] Trial 256 finished with value: 0.5081832726450933 and parameters: {'n_estimators': 350, 'learning_rate': 0.2968802190731981, 'max_depth': 9, 'num_leaves': 11, 'min_data_in_leaf': 200, 'min_child_samples': 5, 'lambda_l1': 1.0984604254136754e-07, 'lambda_l2': 3.263654045312949e-06, 'min_gain_to_split': 5.20781785472238, 'feature_fraction': 0.8217180972965641, 'bagging_fraction': 0.4130410980988764, 'bagging_freq': 1, 'colsample_bytree': 0.3}. Best is trial 234 with value: 0.4959712238237285.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=5.8272405358905175, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=5.8272405358905175
# [LightGBM] [Warning] feature_fraction is set=0.8240056708776622, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8240056708776622
# [LightGBM] [Warning] bagging_fraction is set=0.6268999382368795, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6268999382368795
# [LightGBM] [Warning] lambda_l2 is set=8.623830621469268e-06, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.623830621469268e-06
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=69 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.0964278569171283e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0964278569171283e-07
# [I 2023-11-18 22:25:51,467] Trial 257 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:52,258] Trial 258 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:53,616] Trial 259 pruned. Trial was pruned at iteration 101.
# [I 2023-11-18 22:25:54,304] Trial 260 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:54,944] Trial 261 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:55,588] Trial 262 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:56,246] Trial 263 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:56,896] Trial 264 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:57,534] Trial 265 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:25:58,212] Trial 266 pruned. Trial was pruned at iteration 1.
# [I 2023-11-18 22:25:58,925] Trial 267 pruned. Trial was pruned at iteration 0.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=7.602717338340114, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.602717338340114
# [LightGBM] [Warning] feature_fraction is set=0.8600424155385014, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8600424155385014
# [LightGBM] [Warning] bagging_fraction is set=0.5946520373615597, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5946520373615597
# [LightGBM] [Warning] lambda_l2 is set=7.65960408615675e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.65960408615675e-07
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=60 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.8753800910159856e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8753800910159856e-07
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=7.602717338340114, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.602717338340114
# [LightGBM] [Warning] feature_fraction is set=0.8600424155385014, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8600424155385014
# [LightGBM] [Warning] bagging_fraction is set=0.5946520373615597, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5946520373615597
# [LightGBM] [Warning] lambda_l2 is set=7.65960408615675e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.65960408615675e-07
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=60 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.8753800910159856e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8753800910159856e-07
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=7.602717338340114, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.602717338340114
# [LightGBM] [Warning] feature_fraction is set=0.8600424155385014, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8600424155385014
# [LightGBM] [Warning] bagging_fraction is set=0.5946520373615597, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5946520373615597
# [LightGBM] [Warning] lambda_l2 is set=7.65960408615675e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.65960408615675e-07
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=60 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.8753800910159856e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8753800910159856e-07
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=7.602717338340114, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=7.602717338340114
# [LightGBM] [Warning] feature_fraction is set=0.8600424155385014, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8600424155385014
# [LightGBM] [Warning] bagging_fraction is set=0.5946520373615597, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5946520373615597
# [LightGBM] [Warning] lambda_l2 is set=7.65960408615675e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.65960408615675e-07
# [LightGBM] [Warning] min_data_in_leaf is set=200, min_child_samples=60 will be ignored. Current value: min_data_in_leaf=200
# [LightGBM] [Warning] lambda_l1 is set=1.8753800910159856e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8753800910159856e-07
# [I 2023-11-18 22:26:07,727] Trial 268 finished with value: 0.5462767255307914 and parameters: {'n_estimators': 100, 'learning_rate': 0.2955971396172163, 'max_depth': 9, 'num_leaves': 11, 'min_data_in_leaf': 200, 'min_child_samples': 60, 'lambda_l1': 1.8753800910159856e-07, 'lambda_l2': 7.65960408615675e-07, 'min_gain_to_split': 7.602717338340114, 'feature_fraction': 0.8600424155385014, 'bagging_fraction': 0.5946520373615597, 'bagging_freq': 1, 'colsample_bytree': 0.3}. Best is trial 234 with value: 0.4959712238237285.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=3.580247165326168, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=3.580247165326168
# [LightGBM] [Warning] feature_fraction is set=0.8260233696149426, colsample_bytree=0.3 will be ignored. Current value: feature_fraction=0.8260233696149426
# [LightGBM] [Warning] bagging_fraction is set=0.44675609908444824, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44675609908444824
# [LightGBM] [Warning] lambda_l2 is set=3.7215476330243584e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.7215476330243584e-07
# [LightGBM] [Warning] min_data_in_leaf is set=7200, min_child_samples=43 will be ignored. Current value: min_data_in_leaf=7200
# [LightGBM] [Warning] lambda_l1 is set=1.0495693998774519e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0495693998774519e-07
# [I 2023-11-18 22:26:08,377] Trial 269 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:09,022] Trial 270 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:09,670] Trial 271 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:10,333] Trial 272 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:10,986] Trial 273 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:11,674] Trial 274 pruned. Trial was pruned at iteration 5.
# [I 2023-11-18 22:26:12,336] Trial 275 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:12,987] Trial 276 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:13,635] Trial 277 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:14,292] Trial 278 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:14,932] Trial 279 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:15,596] Trial 280 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:16,253] Trial 281 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:16,898] Trial 282 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:17,548] Trial 283 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:18,200] Trial 284 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:18,856] Trial 285 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:19,501] Trial 286 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:20,253] Trial 287 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:21,046] Trial 288 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:21,720] Trial 289 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:22,353] Trial 290 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:22,986] Trial 291 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:23,633] Trial 292 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:24,641] Trial 293 pruned. Trial was pruned at iteration 46.
# [I 2023-11-18 22:26:25,294] Trial 294 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:26,267] Trial 295 pruned. Trial was pruned at iteration 31.
# [I 2023-11-18 22:26:26,938] Trial 296 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:27,585] Trial 297 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:28,294] Trial 298 pruned. Trial was pruned at iteration 0.
# [I 2023-11-18 22:26:28,964] Trial 299 pruned. Trial was pruned at iteration 0.
# CPU times: user 1h 13min 24s, sys: 2min 34s, total: 1h 15min 58s
# Wall time: 26min 2s

# %%
# Affichage des résultats de l'optimisation
print(f"\tBest value : {study.best_value:.5f}")
print(f"\tBest params:")

# Affichage des meilleurs paramètres
for key, value in study.best_params.items():
    print(f"\t\t{key}: {value}")
# Out:
# 	Best value : 0.49597
# 	Best params:
# 		n_estimators: 350
# 		learning_rate: 0.29578591363554246
# 		max_depth: 9
# 		num_leaves: 11
# 		min_data_in_leaf: 200
# 		min_child_samples: 48
# 		lambda_l1: 6.135724939681604e-07
# 		lambda_l2: 1.1411214145735334e-06
# 		min_gain_to_split: 5.259767088906032
# 		feature_fraction: 0.8125333472167978
# 		bagging_fraction: 0.4539733800806297
# 		bagging_freq: 1
# 		colsample_bytree: 0.3

# %%
from optuna.visualization.matplotlib import plot_optimization_history
# Affichage de l'historique de l'optimisation
plot_optimization_history(study);

# %%
# Affichage des meilleurs paramètres trouvés par Optuna
study.best_params
# Out:
# {'n_estimators': 350,
#  'learning_rate': 0.29578591363554246,
#  'max_depth': 9,
#  'num_leaves': 11,
#  'min_data_in_leaf': 200,
#  'min_child_samples': 48,
#  'lambda_l1': 6.135724939681604e-07,
#  'lambda_l2': 1.1411214145735334e-06,
#  'min_gain_to_split': 5.259767088906032,
#  'feature_fraction': 0.8125333472167978,
#  'bagging_fraction': 0.4539733800806297,
#  'bagging_freq': 1,
#  'colsample_bytree': 0.3}

# %% [markdown]
# ## Performance du modèle

# %%
# Séparation de l'ensemble X_train en deux sous-ensembles : un pour l'entraînement et un pour la validation
X_train, X_valid, y_train, y_valid = train_test_split(X, y, stratify=y, test_size=0.33, random_state=101)
# Affichage des dimensions des ensembles résultants
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((29522, 59), (14541, 59), (29522, 1), (14541, 1))

# %%
# Définition du modèle LGBMClassifier avec les paramètres optimaux trouvés par Optuna
model_LGBM = LGBMClassifier(objective="binary",
                            class_weight="balanced",
                            verbose=-1,
                            boosting_type="gbdt",
                            n_estimators=500,
                            learning_rate=0.29734997673606356,
                            max_depth=11,
                            num_leaves=11,
                            min_data_in_leaf=200,
                            min_child_samples=98,
                            lambda_l1=0.9037886944882865,
                            lambda_l2=0.011906183063897397,
                            min_gain_to_split=0.007551036778260303,
                            feature_fraction=0.9658507086246584,
                            bagging_fraction=0.8476232920140797,
                            bagging_freq=7,
                            colsample_bytree=0.3,
                            random_state=101,
                            n_jobs=-2,)

# Entraînement du modèle sur l'ensemble d'entraînement
model_LGBM_fit = model_LGBM.fit(X_train, y_train)

# Prédictions sur l'ensemble de validation
y_pred_lgbm = model_LGBM_fit.predict(X_valid)
# Probabilités prédites sur l'ensemble de validation
y_pred_lgbm_proba = model_LGBM_fit.predict_proba(X_valid)

# %% [markdown]
# ![confusionMatrxiUpdated.jpg](attachment:confusionMatrxiUpdated.jpg)

# %%
from yellowbrick.classifier import ConfusionMatrix
# Définition des classes pour la matrice de confusion
classes = ['not_difficulty_payment', 'is_difficulty_payment']
# Configuration du style seaborn
sns.set_style("ticks")

# Création de la figure et de l'axe
fig, ax = plt.subplots(figsize=(6, 4))
# Initialisation et ajustement de la matrice de confusion avec le modèle LGBM
cm = ConfusionMatrix(model_LGBM_fit, classes=classes)

cm.fit(X_train, y_train)        # Ajustement du visualiseur et du modèle sur l'ensemble d'entraînement
cm.score(X_valid, y_valid)        # Évaluation du modèle sur l'ensemble de validation
cm.show()                      # Affichage de la matrice de confusion
# Out:
# <Axes: title={'center': 'LGBMClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Impression du rapport de classification
print(classification_report(y_valid, y_pred_lgbm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91     13368
#            1       0.20      0.34      0.25      1173
#
#     accuracy                           0.84     14541
#    macro avg       0.57      0.61      0.58     14541
# weighted avg       0.88      0.84      0.85     14541

# %%
# Identification des classes. La variable classes sera utile lors de l'utilisation des visualiseurs de Yellowbrick
classes = ['not_difficulty_payment', 'is_difficulty_payment']

sns.set_style("ticks")
fig, ax = plt.subplots(figsize=(6, 4))
# Création d'un visualiseur de rapport de classification
visualizer = ClassificationReport(model_LGBM_fit, classes=classes, support=True, cmap='PRGn')

visualizer.fit(X_train, y_train)        # Adapter le visualiseur et le modèle aux données d'entraînement
visualizer.score(X_valid, y_valid)       # Évaluer le modèle sur les données de validation
visualizer.show()                       # Finaliser et afficher la figure
# Out:
# <Axes: title={'center': 'LGBMClassifier Classification Report'}>

# %%
# Affichage de la précision sur l'ensemble d'entraînement
print(f"Train Accuracy : {accuracy_score(y_train, model_LGBM_fit.predict(X_train)):.2%}")
# Affichage de la précision sur l'ensemble de validation
print(f"Test Accuracy : {accuracy_score(y_valid, y_pred_lgbm):.2%}")
# Out:
# Train Accuracy : 92.41%
# Test Accuracy : 83.50%

# %%
# Affichage de la précision sur l'ensemble d'entraînement
print(f"Train Precision : {precision_score(y_train, model_LGBM_fit.predict(X_train)):.2%}")
# Affichage de la précision sur l'ensemble de validation
print(f"Test Precision : {precision_score(y_valid, y_pred_lgbm):.2%}")
# Out:
# Train Precision : 51.54%
# Test Precision : 19.80%

# %%
# Affichage de la précision sur l'ensemble d'entraînement
print(f"Train Recall : {recall_score(y_train, model_LGBM_fit.predict(X_train)):.2%}")
# Affichage de la précision sur l'ensemble de validation
print(f"Test Recall : {recall_score(y_valid, y_pred_lgbm):.2%}")
# Out:
# Train Recall : 99.54%
# Test Recall : 34.27%

# %%
# Affichage de la précision sur l'ensemble d'entraînement
print(f"Train f1_score : {f1_score(y_train, model_LGBM_fit.predict(X_train)):.2%}")
# Affichage de la précision sur l'ensemble de validation
print(f"Test f1_score : {f1_score(y_valid, y_pred_lgbm):.2%}")
# Out:
# Train f1_score : 67.92%
# Test f1_score : 25.10%

# %%
# Affichage de la précision sur l'ensemble d'entraînement
print(f"Train f2_score : {fbeta_score(y_train, model_LGBM_fit.predict(X_train), beta=2):.2%}")
# Affichage de la précision sur l'ensemble de validation
print(f"Test f2_score : {fbeta_score(y_valid, y_pred_lgbm, beta=2):.2%}")
# Out:
# Train f2_score : 83.91%
# Test f2_score : 29.90%

# %%
# Affichage de la précision sur l'ensemble d'entraînement
print(f"Train ROC-AUC : {roc_auc_score(y_train, model_LGBM_fit.predict(X_train)):.2%}")
# Affichage de la précision sur l'ensemble de validation
print(f"Test ROC-AUC : {roc_auc_score(y_valid, y_pred_lgbm):.2%}")
# Out:
# Train ROC-AUC : 95.66%
# Test ROC-AUC : 61.05%

# %%
from yellowbrick.classifier import ROCAUC

# Définir les classes pour les visualiseurs Yellowbrick
sns.set_style("ticks")
fig, ax = plt.subplots(figsize=(6, 4))
# Initialiser le visualiseur ROC-AUC
vis_rocauc = ROCAUC(model_LGBM_fit, classes=classes, random_state=101)
# Entraîner le visualiseur sur les données d'entraînement
vis_rocauc.fit(X_train, y_train)  
# Évaluer le modèle sur les données de test
vis_rocauc.score(X_valid, y_valid)
# Afficher le graphique ROC-AUC
vis_rocauc.show()
# Out:
# <Axes: title={'center': 'ROC Curves for LGBMClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
from yellowbrick.classifier import PrecisionRecallCurve

# Définir les classes pour les visualiseurs Yellowbrick
sns.set_style("ticks")
fig, ax = plt.subplots(figsize=(6, 4))
# Initialiser le visualiseur de courbe précision-rappel
vis_prc = PrecisionRecallCurve(model_LGBM_fit, random_state=101)
# Entraîner le visualiseur sur les données d'entraînement
vis_prc.fit(X_train, y_train)
# Évaluer le modèle sur les données de test
vis_prc.score(X_valid, y_valid)   
# Afficher le graphique de la courbe précision-rappel
vis_prc.show()
# Out:
# <Axes: title={'center': 'Precision-Recall Curve for LGBMClassifier'}, xlabel='Recall', ylabel='Precision'>

# %%
from sklearn.metrics import precision_recall_curve, roc_curve
# Définition de la fonction pour tracer la courbe de précision/rappel en fonction du seuil
def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    # Tracé de la précision en fonction du seuil (en tirets bleus)
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision")
    # Tracé du rappel en fonction du seuil (en tirets verts)
    plt.plot(thresholds, recalls[:-1], "g--", label="Recall")
    # Configuration de l'axe des x
    plt.xlabel("Threshold")
    # Légende en haut à gauche
    plt.legend(loc="upper left")
     # Titre du graphique
    plt.title("Precision/Recall Tradeoff")
    
# Définition de la fonction pour tracer la courbe ROC
def plot_roc_curve(fpr, tpr, label=None):
    # Tracé de la courbe ROC avec une ligne de couleur et une étiquette optionnelle
    plt.plot(fpr, tpr, linewidth=2, label=label)
    # Ligne en pointillés diagonale (aléatoire)
    plt.plot([0, 1], [0, 1], "k--")
    # Configuration des axes
    plt.axis([0, 1, 0, 1])
    # Étiquettes des axes
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    # Titre du graphique
    plt.title('ROC Curve')

# %%
precisions, recalls, thresholds = precision_recall_curve(y_valid, y_pred_lgbm)

# Tracer la courbe de précision en fonction du seuil de décision
plt.figure(figsize=(14, 25))
plt.subplot(4, 2, 1)
plot_precision_recall_vs_threshold(precisions, recalls, thresholds)
# Tracer la courbe PR (Precision/Recall)
plt.subplot(4, 2, 2)
plt.plot(precisions, recalls)
plt.xlabel("Precision")
plt.ylabel("Recall")
plt.title("PR Curve: precisions/recalls tradeoff");
# Tracer la courbe ROC (Receiver Operating Characteristic)
plt.subplot(4, 2, 3)
fpr, tpr, thresholds = roc_curve(y_valid, y_pred_lgbm)
plot_roc_curve(fpr, tpr)
